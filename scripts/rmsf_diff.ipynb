# %%
# %pylab inline
import gromacs.formats
import pandas as pd
rc('font', family='serif', size=15)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
temps = ('300','373','473','573')
print len(temps)
# Out:
# 4

# %%
for t in temps:
    fig, ax = plt.subplots(figsize=(20, 10))    
    rmsf_h = gromacs.formats.XVG('/home/gerry/heat/cd4/rmsf/H_unbound/H_unbound_rmsf_'+t+'k.xvg').array[1]
    rmsf_h1 = gromacs.formats.XVG('/home/gerry/heat/cd4/rmsf/H_unbound/H_unbound_rmsf_'+t+'k1.xvg').array[1]
    rmsf_h = (rmsf_h+rmsf_h1)/2
    rmsf_h2 = gromacs.formats.XVG('/home/gerry/heat/cd4/rmsf/H_unbound/H_unbound_rmsf_'+t+'k2.xvg').array[1]
    rmsf_h = (rmsf_h+rmsf_h2)/2
    
    rmsf_r2 = gromacs.formats.XVG('/home/gerry/heat/cd4/rmsf/R2_unbound/R2_unbound_rmsf_'+t+'k.xvg').array[1]
    rmsf_r21 = gromacs.formats.XVG('/home/gerry/heat/cd4/rmsf/R2_unbound/R2_unbound_rmsf_'+t+'k1.xvg').array[1]
    rmsf_r2 = (rmsf_r2+rmsf_r21)/2
    rmsf_r22 = gromacs.formats.XVG('/home/gerry/heat/cd4/rmsf/R2_unbound/R2_unbound_rmsf_'+t+'k2.xvg').array[1]
    rmsf_r2 = (rmsf_r2+rmsf_r22)/2
        
    plot(range(1,103), rmsf_h[0:102], color='darkorange', linewidth=1, label='H061.14-gp120')
    plot(range(104,108), rmsf_h[102:106], color='darkorange', linewidth=1)
    plot(range(115,119), rmsf_h[106:110], color='darkorange', linewidth=1)
    plot(range(123,381), rmsf_h[110:368], color='darkorange', linewidth=1)
    plot(range(388,396), rmsf_h[368:376], color='darkorange', linewidth=1)    
    plot(range(397,451), rmsf_h[376:430], color='darkorange', linewidth=1)
    plot(range(456,493), rmsf_h[430:], color='darkorange', linewidth=1)

    plot(range(1,119), rmsf_r2[0:118], color='g', linewidth=1,label='R2-gp120')    
    plot(range(124,132), rmsf_r2[118:126], color='g', linewidth=1)
    plot(range(133,168), rmsf_r2[126:161], color='g', linewidth=1)
    plot(range(170,171), rmsf_r2[161:162], color='g', linewidth=1)
    plot(range(175,394), rmsf_r2[162:381], color='g', linewidth=1)
    plot(range(395,493), rmsf_r2[381:479], color='g', linewidth=1)

    fill_between(range(1,103), 0, rmsf_r2[0:102]-rmsf_h[0:102], color='r', where=rmsf_r2[0:102]-rmsf_h[0:102]>0, interpolate=True, alpha=0.3)
    fill_between(range(104,108), 0, rmsf_r2[103:107]-rmsf_h[102:106], color='r', where=rmsf_r2[103:107]-rmsf_h[102:106]>0, interpolate=True, alpha=0.3)
    fill_between(range(115,119), 0, rmsf_r2[114:118]-rmsf_h[106:110], color='r', where=rmsf_r2[114:115]-rmsf_h[106:110]>0, interpolate=True, alpha=0.3)
    fill_between(range(124,132), 0, rmsf_r2[118:126]-rmsf_h[111:119], color='r', where=rmsf_r2[118:126]-rmsf_h[111:119]>0, interpolate=True, alpha=0.3)
    fill_between(range(133,168), 0, rmsf_r2[126:161]-rmsf_h[120:155], color='r', where=rmsf_r2[126:161]-rmsf_h[120:155]>0, interpolate=True, alpha=0.3)
    fill_between(range(170,171), 0, rmsf_r2[161:162]-rmsf_h[157:158], color='r', where=rmsf_r2[161:162]-rmsf_h[157:158]>0, interpolate=True, alpha=0.3)
    fill_between(range(175,381), 0, rmsf_r2[162:368]-rmsf_h[162:368], color='r', where=rmsf_r2[162:368]-rmsf_h[162:368]>0, interpolate=True, alpha=0.3)
    fill_between(range(388,394), 0, rmsf_r2[375:381]-rmsf_h[368:374], color='r', where=rmsf_r2[375:381]-rmsf_h[368:374]>0, interpolate=True, alpha=0.3)
    fill_between(range(395,396), 0, rmsf_r2[381:382]-rmsf_h[375:376], color='r', where=rmsf_r2[381:382]-rmsf_h[375:376]>0, interpolate=True, alpha=0.3)
    fill_between(range(397,451), 0, rmsf_r2[383:437]-rmsf_h[376:430], color='r', where=rmsf_r2[383:437]-rmsf_h[376:430]>0, interpolate=True, alpha=0.3)
    fill_between(range(456,493), 0, rmsf_r2[442:]-rmsf_h[430:], color='r', where=rmsf_r2[442:]-rmsf_h[430:]>0, interpolate=True, alpha=0.3)

    fill_between(range(1,103), 0, rmsf_r2[0:102]-rmsf_h[0:102], color='r', where=rmsf_r2[0:102]-rmsf_h[0:102]>0.05, interpolate=True, alpha=0.9)
    fill_between(range(104,108), 0, rmsf_r2[103:107]-rmsf_h[102:106], color='r', where=rmsf_r2[103:107]-rmsf_h[102:106]>0.05, interpolate=True, alpha=0.9)
    fill_between(range(115,119), 0, rmsf_r2[114:118]-rmsf_h[106:110], color='r', where=rmsf_r2[114:115]-rmsf_h[106:110]>0.05, interpolate=True, alpha=0.9)
    fill_between(range(124,132), 0, rmsf_r2[118:126]-rmsf_h[111:119], color='r', where=rmsf_r2[118:126]-rmsf_h[111:119]>0.05, interpolate=True, alpha=0.9)
    fill_between(range(133,168), 0, rmsf_r2[126:161]-rmsf_h[120:155], color='r', where=rmsf_r2[126:161]-rmsf_h[120:155]>0.05, interpolate=True, alpha=0.9)
    fill_between(range(170,171), 0, rmsf_r2[161:162]-rmsf_h[157:158], color='r', where=rmsf_r2[161:162]-rmsf_h[157:158]>0.05, interpolate=True, alpha=0.9)
    fill_between(range(175,381), 0, rmsf_r2[162:368]-rmsf_h[162:368], color='r', where=rmsf_r2[162:368]-rmsf_h[162:368]>0.05, interpolate=True, alpha=0.9)
    fill_between(range(388,394), 0, rmsf_r2[375:381]-rmsf_h[368:374], color='r', where=rmsf_r2[375:381]-rmsf_h[368:374]>0.05, interpolate=True, alpha=0.9)
    fill_between(range(395,396), 0, rmsf_r2[381:382]-rmsf_h[375:376], color='r', where=rmsf_r2[381:382]-rmsf_h[375:376]>0.05, interpolate=True, alpha=0.9)
    fill_between(range(397,451), 0, rmsf_r2[383:437]-rmsf_h[376:430], color='r', where=rmsf_r2[383:437]-rmsf_h[376:430]>0.05, interpolate=True, alpha=0.9)
    fill_between(range(456,493), 0, rmsf_r2[442:]-rmsf_h[430:], color='r', where=rmsf_r2[442:]-rmsf_h[430:]>0.05, interpolate=True, alpha=0.9)

    fill_between(range(1,103), 0, rmsf_r2[0:102]-rmsf_h[0:102], color='b', where=rmsf_r2[0:102]-rmsf_h[0:102]<0, interpolate=True, alpha=0.3)
    fill_between(range(104,108), 0, rmsf_r2[103:107]-rmsf_h[102:106], color='b', where=rmsf_r2[103:107]-rmsf_h[102:106]<0, interpolate=True, alpha=0.3)
    fill_between(range(115,119), 0, rmsf_r2[114:118]-rmsf_h[106:110], color='b', where=rmsf_r2[114:115]-rmsf_h[106:110]<0, interpolate=True, alpha=0.3)
    fill_between(range(124,132), 0, rmsf_r2[118:126]-rmsf_h[111:119], color='b', where=rmsf_r2[118:126]-rmsf_h[111:119]<0, interpolate=True, alpha=0.3)
    fill_between(range(133,168), 0, rmsf_r2[126:161]-rmsf_h[120:155], color='b', where=rmsf_r2[126:161]-rmsf_h[120:155]<0, interpolate=True, alpha=0.3)
    fill_between(range(170,171), 0, rmsf_r2[161:162]-rmsf_h[157:158], color='b', where=rmsf_r2[161:162]-rmsf_h[157:158]<0, interpolate=True, alpha=0.3)
    fill_between(range(175,381), 0, rmsf_r2[162:368]-rmsf_h[162:368], color='b', where=rmsf_r2[162:368]-rmsf_h[162:368]<0, interpolate=True, alpha=0.3)
    fill_between(range(388,394), 0, rmsf_r2[375:381]-rmsf_h[368:374], color='b', where=rmsf_r2[375:381]-rmsf_h[368:374]<0, interpolate=True, alpha=0.3)
    fill_between(range(395,396), 0, rmsf_r2[381:382]-rmsf_h[375:376], color='b', where=rmsf_r2[381:382]-rmsf_h[375:376]<0, interpolate=True, alpha=0.3)
    fill_between(range(397,451), 0, rmsf_r2[383:437]-rmsf_h[376:430], color='b', where=rmsf_r2[383:437]-rmsf_h[376:430]<0, interpolate=True, alpha=0.3)
    fill_between(range(456,493), 0, rmsf_r2[442:]-rmsf_h[430:], color='b', where=rmsf_r2[442:]-rmsf_h[430:]<0, interpolate=True, alpha=0.3)

    x = np.arange(0,500)
    plot(x, [0 for i in x], color='0.75', linewidth=1)
    m_rmsf_r2 = mean(rmsf_r2)
    m_rmsf_h = mean(rmsf_h)
    plot(x, [m_rmsf_r2 for i in x], color='g', linestyle='--', linewidth=1)
    plot(x, [m_rmsf_h for i in x], color='darkorange', linestyle='--', linewidth=1)
    print ('CD4-independent mean %f ') % m_rmsf_r2
    print ('CD4-dependent mean %f ') % m_rmsf_h

    legend()
    xlim(0,486)
    x_ticks = [0, 9, 19, 29, 39, 49, 59, 69, 79, 89, 99, 117, 127, 138, 148, 158, 168, 182, 192, 202, 212, 222, 232, 242, 252, 262, 272, 282, 292, 302, 312, 322, 332, 342, 352, 362, 372, 390, 402, 412, 422, 432, 442, 452, 463, 473, 483, 492]
    x_label = [31,40,'', '', '', '', '', 100, '', '', '', '', 150,  '',  '',  '', '', 200,  '',  '',  '', '', 250,  '',  '',  '', '',  300,  '',  '',  '', '',  350,  '',  '',  '', '',  400,  '',  '',  '', '',  450,  '',  '',  '', '',  499]
    xticks(x_ticks,x_label)

    ylim(-0.5,1.5)
    yticks([-0.5,0,0.5,1.0,1.5])
    xlabel("Index of structurally equivalent positions")
    ylabel(r"C$_\alpha$ RMSF (nm)")

    region_ticks = [67,80, 89,91, 102, 134,144, 150,159, 162,164, 177,179, 186, 188,189, 285,316, 320,340, 389,411, 412,414, 421,423, 449,462, 466,475]
    ax.set_xticks(region_ticks, minor=True)
    ax.grid(which='minor', axis='x', linewidth=1)
# Out:
# CD4-independent mean 0.140584
# CD4-dependent mean 0.121234
# CD4-independent mean 0.151353
# CD4-dependent mean 0.141537
# CD4-independent mean 0.230488
# CD4-dependent mean 0.208658
# CD4-independent mean 0.456699
# CD4-dependent mean 0.417394
